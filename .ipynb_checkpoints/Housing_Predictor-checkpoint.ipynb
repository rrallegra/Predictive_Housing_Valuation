# %% [markdown]
# # Housing Valuation Predictor
#
# # US - California

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.neighbors import KNeighborsClassifier

# %%
us_housing = pd.read_csv("US_CA_housing_data.csv")

# %%
us_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
us_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
us_housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
us_housing["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
# %matplotlib inline

us_housing.hist(bins=50, figsize=(20,20), color="royalblue")
plt.show()

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(us_housing, test_size = 0.2, random_state = 42)

# %%
us_housing.plot(kind = "scatter", x= "longitude", y = "latitude", color="red" )

# %%
us_housing.plot(kind = "scatter", x = "longitude", y = "latitude", alpha = 0.8, s = us_housing["population"]/100, 
             label = "population", figsize = (15,10), c = "median_house_value", cmap = plt.get_cmap("jet"), colorbar = True)

plt.legend()

# %%
us_housing.plot(kind = "scatter", x= "longitude", y = "latitude", alpha = 0.8, s = us_housing["population"]/100, 
             label = "population", figsize=(15,10), c= "median_income", cmap = plt.get_cmap("jet"), colorbar = True)
plt.legend()

# %%
from pandas.plotting import scatter_matrix
attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age"]
scatter_matrix(us_housing[attributes], figsize=(12, 8), color="green")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000217323840F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002173228A198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021732E5B550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000217323B8CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021732FD4C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021732FD4C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021733010710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002173236AC50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002173234C2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021731E4A2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002173230AA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000217321DDD30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021731EDA2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021731F14E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002173218B7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021732160908>]], dtype=object)

# %%
us_housing.plot(kind="scatter", x= "median_income" , y= "median_house_value", color = "red")
plt.show()

# %%
us_housing.isnull().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms         True
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool

# %%
us_housing = pd.get_dummies(us_housing)
us_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                          0                       0                       0
# 1                          0                       0                       0
# 2                          0                       0                       0
# 3                          0                       0                       0
# 4                          0                       0                       0
#
#    ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 0                         1                           0
# 1                         1                           0
# 2                         1                           0
# 3                         1                           0
# 4                         1                           0

# %%
X = us_housing.iloc[:,:-1].values
y = us_housing.iloc[:,-1].values.reshape(-1,1)

# X = us_housing[['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND', 'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN' ]]
# y = us_housing["median_house_value"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (20640, 13) (20640, 1)

# %%
from sklearn.preprocessing import Imputer
imputerNaN = Imputer(missing_values="NaN",strategy="mean",axis=0)
X[:,[4]] = imputerNaN.fit_transform(X[:,[4]])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
X[:,8] = LabelEncoder().fit_transform(X[:,8])
X = OneHotEncoder(categorical_features=[8]).fit_transform(X).toarray()

# %%
#  Multivariate Linear Regression

# Split into training set and testing set in every model building cause of "random_state" present in the "train_test_split"
X_train,X_test,y_train,y_test = tts(X,y,test_size=0.2,random_state=28)

model_multivariate = LinearRegression()
model_multivariate.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = model_multivariate.predict(X_test)

print("Model Score for Training data: {}".format(model_multivariate.score(X_train,y_train)))
print("Model Score for Testing data: {}".format(r2_score(y_test,y_pred)))
print("Root Mean Squared Error is {}".format(np.sqrt(mean_squared_error(y_test,y_pred))))
# Out:
# Model Score for Training data: 1.0
# Model Score for Testing data: 1.0
# Root Mean Squared Error is 2.1795523644250264e-13

# %%
# Decision Tree Regression

# Split into training set and testing set in every model building cause of "random_state" present in the "train_test_split"
X_train,X_test,y_train,y_test = tts(X,y,test_size=0.2,random_state=5)

model_decision = DecisionTreeRegressor(random_state=48)
model_decision.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=48, splitter='best')

# %%
y_pred = model_decision.predict(X_test)

print("Model Score for Training data: {}".format(model_decision.score(X_train,y_train)))
print("Model Score for Testing data: {}".format(r2_score(y_test,y_pred)))
print("Root Mean Squared Error is {}".format(np.sqrt(mean_squared_error(y_test,y_pred))))
# Out:
# Model Score for Training data: 1.0
# Model Score for Testing data: 0.9978990987194579
# Root Mean Squared Error is 0.015564320159117259

# %%
# Random Forest Regression
X_train,X_test,y_train,y_test = tts(X,y,test_size=0.2,random_state=5)

model_random = RandomForestRegressor(n_estimators=35,random_state=15)
model_random.fit(X_train,y_train.ravel())
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=35, n_jobs=1,
#            oob_score=False, random_state=15, verbose=0, warm_start=False)

# %%
y_pred = model_random.predict(X_test)

print("Model Score for Training data: {}".format(model_random.score(X_train,y_train)))
print("Model Score for Testing data: {}".format(r2_score(y_test,y_pred)))
print("Root Mean Squared Error is {}".format(np.sqrt(mean_squared_error(y_test,y_pred))))
# Out:
# Model Score for Training data: 0.999961837879189
# Model Score for Testing data: 0.9999639845494764
# Root Mean Squared Error is 0.0020378478648480566

# %%
# Support Vector Machine Regression (SVM)
X_train,X_test,y_train,y_test = tts(X,y,test_size=0.2,random_state=24)

from sklearn.preprocessing import StandardScaler
X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)
y_train = StandardScaler().fit_transform(y_train).ravel()
y_test = StandardScaler().fit_transform(y_test).ravel()
# Out:
# C:\Users\PC\Anaconda3\envs\pythonData\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Support Vector Regression

from sklearn.svm import SVR
model_svr = SVR(kernel="rbf")
model_svr.fit(X_train,y_train.ravel())
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = model_svr.predict(X_test)

print("Model Score for Training data: {}".format(model_svr.score(X_train,y_train)))
print("Model Score for Testing data: {}".format(r2_score(y_test,y_pred)))
print("Root Mean Squared Error is {}".format(np.sqrt(mean_squared_error(y_test,y_pred))))
# Out:
# Model Score for Training data: 0.34255964461958355
# Model Score for Testing data: 0.32321447020582283
# Root Mean Squared Error is 0.8226697574325783
